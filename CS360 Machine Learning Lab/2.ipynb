# %% [markdown]
# **Assignment 2**

# %% [markdown]
# 1.

# %%
import pandas as pd
import numpy as np
df= pd.read_csv('/content/drive/MyDrive/Other-Material/salary_data.csv',header=0).astype('float64')
mat=df.to_numpy()
print("Shape of matrix loaded:",mat.shape)
print("Number of Features:",mat.shape[1]-1)
print("Number of Patterns:",mat.shape[0])
op=mat[:,1]
print("Range:",np.min(op),np.max(op))
# Out:
# Shape of matrix loaded: (30, 2)
# Number of Features: 1
# Number of Patterns: 30
# Range: 37731.0 122391.0

# %% [markdown]
# 2.

# %%
ten_pc=int(mat.shape[0]/10)
splits=np.arange(ten_pc,mat.shape[0]-ten_pc+1,ten_pc)
print("dataset split in X=10:10:90 and Y=90:-10:10")
for i in splits:
  X=mat[:i,:]
  Y=mat[i:,:]
  print("X:",X.shape,"Y:",Y.shape)
# Out:
# dataset split in X=10:10:90 and Y=90:-10:10
# X: (3, 2) Y: (27, 2)
# X: (6, 2) Y: (24, 2)
# X: (9, 2) Y: (21, 2)
# X: (12, 2) Y: (18, 2)
# X: (15, 2) Y: (15, 2)
# X: (18, 2) Y: (12, 2)
# X: (21, 2) Y: (9, 2)
# X: (24, 2) Y: (6, 2)
# X: (27, 2) Y: (3, 2)

# %% [markdown]
# 3.

# %%
from scipy import stats

print("Means:")
print("Row wise:",mat.mean(axis=1))
print("Column wise:",mat.mean(axis=0))
print("Overall:",mat.reshape(1,mat.shape[1]*mat.shape[0]).mean(axis=1))

print("\nMedian")
print("Row Wise",np.median(mat,axis=1))
print("Column Wise",np.median(mat,axis=0))
print("Overall",np.median(mat.reshape(1,mat.shape[1]*mat.shape[0]),axis=1))

print("\nMode")
print("Row Wise:",stats.mode(np.transpose(mat))[0])
print("Column Wise:",stats.mode(mat)[0])
print("Overall:",stats.mode(mat.reshape(mat.shape[1]*mat.shape[0],1))[0])

print("\nStandard Deviation")
print("Row Wise:",np.std(mat,axis=1))
print("Column Wise:",np.std(mat,axis=0))
print("Overall:",np.std(mat))
# Out:
# Means:
# Row wise: [19672.05 23103.15 18866.25 21763.5  19946.6  28322.45 30076.5  27224.1
#  32224.1  28596.35 31610.95 27899.   28480.5  28542.55 30557.75 33971.45
#  33017.05 41546.65 40684.45 46973.   45872.4  49140.05 50654.95 56910.1
#  54719.85 52795.5  58489.25 56322.3  61200.65 60941.25]
# Column wise: [5.31333333e+00 7.60030000e+04]
# Overall: [38004.15666667]
#
# Median
# Row Wise [19672.05 23103.15 18866.25 21763.5  19946.6  28322.45 30076.5  27224.1
#  32224.1  28596.35 31610.95 27899.   28480.5  28542.55 30557.75 33971.45
#  33017.05 41546.65 40684.45 46973.   45872.4  49140.05 50654.95 56910.1
#  54719.85 52795.5  58489.25 56322.3  61200.65 60941.25]
# Column Wise [4.7000e+00 6.5237e+04]
# Overall [18870.75]
#
# Mode
# Row Wise: [[ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#    4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#   10.3 10.5]]
# Column Wise: [[3.2000e+00 3.7731e+04]]
# Overall: [[3.2]]
#
# Standard Deviation
# Row Wise: [19670.95 23101.85 18864.75 21761.5  19944.4  28319.55 30073.5  27220.9
#  32220.9  28592.65 31607.05 27895.   28476.5  28538.45 30553.25 33966.55
#  33011.95 41541.35 40678.55 46967.   45865.6  49132.95 50647.05 56901.9
#  54711.15 52786.5  58479.75 56312.7  61190.35 60930.75]
# Column Wise: [2.79018916e+00 2.69536502e+04]
# Overall: 42510.724875382395

# %% [markdown]
# 4.

# %%
def eq(ip):
  para=30000
  return ip*para

sumSquareError=0
for i in range(0,mat.shape[1]):
  sumSquareError=sumSquareError+(mat[i][1]-eq(mat[i][0]))**2
print("The SumSquareError:",sumSquareError)
# Out:
# The SumSquareError: 92145674.0
